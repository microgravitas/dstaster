# %%
from dstaster import *

import folium # This notebook needs folium installed in order to display maps

# %%
cultural = pd.read_csv('datasets/inner_london_cultural.csv')
cultural
# Out:
#       Unnamed: 0         borough      type                       site_name  \
# 0              0  City of London  Archives                  Baring Archive
# 1              1  City of London  Archives         LexisNexis Butterworths
# 2              2  City of London  Archives     Employment Policy Institute
# 3              3  City of London  Archives       Prudential Group Archives
# 4              4  City of London  Archives  Chartered Insitute of Taxation
# ...          ...             ...       ...                             ...
# 2990         888          Camden  Theatres             Pentameters Theatre
# 2991         889          Camden  Theatres                Platform Theatre
# 2992         890          Camden  Theatres                       The Place
# 2993         891          Camden  Theatres                     Kings Place
# 2994         892          Camden  Theatres                 Peacock Theatre
#
#                borough_name   latitude  longitude
# 0     City and County of th  51.515517  -0.089226
# 1     City and County of th  51.516313  -0.111522
# 2     City and County of th  51.515068  -0.075887
# 3     City and County of th  51.510391  -0.089040
# 4     City and County of th  51.515205  -0.110328
# ...                     ...        ...        ...
# 2990                 Camden  51.556282  -0.180041
# 2991                 Camden  51.537431  -0.125196
# 2992                 Camden  51.527811  -0.130565
# 2993                 Camden  51.534748  -0.123577
# 2994                 Camden  51.515137  -0.119599
#
# [2995 rows x 7 columns]

# %% [markdown]
# <h2>Plot on map</h2>

# %%
def positions(text):
    index = cultural['type'] == text
    return cultural.loc[index, ['latitude', 'longitude']].iterrows()

# %%
pos = [51.517, -0.12] 

mp = folium.Map(location=pos, tiles='Stamen Toner', zoom_start=14, zoom_control=False)
        
for i, pos in positions("Commercial galleries"):
    folium.Circle(
        radius=10,
        location=pos.values,
        color=colors['blue'],
        fill=True,
        fill_opacity=1.0
    ).add_to(mp)
    
for i, pos in positions("Jewellery design"):
    folium.Circle(
        radius=10,
        location=pos.values,
        color=colors['salmon'],
        fill=True,
        fill_opacity=1.0
    ).add_to(mp)

        
mp
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
from itertools import chain 

a = np.array([51.512824, -0.117294])
b = np.array([51.527226, -0.130642])
diff = b-a
print(diff)
orth = np.array([-diff[1], diff[0]])
print(orth)

 
mp = folium.Map(location=pos, tiles='Stamen Toner', zoom_start=14, zoom_control=False)
    

for i, pos in chain(positions("Commercial galleries"), positions("Jewellery design")):
    if np.dot(pos.values-a, orth) < 0:
        color = 'blue' # Gallery
    else:
        color = 'salmon' # Jewellery
    folium.Circle(
        radius=10,
        location=pos.values,
        color=colors[color],
        fill=True,
        fill_opacity=1.0
    ).add_to(mp)


folium.PolyLine([a-diff,b+diff], color='white', weight=10, opacity=1).add_to(mp)
folium.PolyLine([a-diff,b+diff], color='green', weight=6, opacity=1).add_to(mp)
      
    
galleries_total = sum(cultural['type'] == "Commercial galleries")
galleries_positive = 0
jewelleries_total = sum(cultural['type'] == "Jewellery design")
jewelleries_positive = 0
for i, pos in positions("Commercial galleries"):
    if np.dot(pos.values-a, orth) < 0:
        galleries_positive += 1
    
for i, pos in positions("Jewellery design"):
    if np.dot(pos.values-a, orth) >= 0:
        jewelleries_positive += 1
  
print(f"Galleries {100*galleries_positive/galleries_total:2f}%")
print(f"Jewelleries {100*jewelleries_positive/jewelleries_total:2f}%")

mp
# Out:
# [ 0.014402 -0.013348]
# [0.013348 0.014402]
# Galleries 80.232558%
# Jewelleries 52.816901%
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import selenium
from PIL import Image

img_data = mp._to_png(5)
img = Image.open(io.BytesIO(img_data))
img.save('test.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/selenium/webdriver/common/service.py in start(self)
#      75                                             stderr=self.log_file,
# ---> 76                                             stdin=PIPE)
#      77         except TypeError:
#
# /usr/lib64/python3.7/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     799                                 errread, errwrite,
# --> 800                                 restore_signals, start_new_session)
#     801         except:
#
# /usr/lib64/python3.7/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1550                             err_msg += ': ' + repr(err_filename)
# -> 1551                     raise child_exception_type(errno_num, err_msg, err_filename)
#    1552                 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'geckodriver': 'geckodriver'
#
# During handling of the above exception, another exception occurred:
#
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-7-bcec77cef08c> in <module>
#       2 from PIL import Image
#       3
# ----> 4 img_data = mp._to_png(5)
#       5 img = Image.open(io.BytesIO(img_data))
#       6 img.save('test.png')
#
# ~/.local/lib/python3.7/site-packages/folium/folium.py in _to_png(self, delay)
#     311             options = webdriver.firefox.options.Options()
#     312             options.add_argument('--headless')
# --> 313             driver = webdriver.Firefox(options=options)
#     314
#     315             html = self.get_root().render()
#
# ~/.local/lib/python3.7/site-packages/selenium/webdriver/firefox/webdriver.py in __init__(self, firefox_profile, firefox_binary, timeout, capabilities, proxy, executable_path, options, service_log_path, firefox_options, service_args, desired_capabilities, log_path, keep_alive)
#     162                 service_args=service_args,
#     163                 log_path=service_log_path)
# --> 164             self.service.start()
#     165
#     166             capabilities.update(options.to_capabilities())
#
# ~/.local/lib/python3.7/site-packages/selenium/webdriver/common/service.py in start(self)
#      81                 raise WebDriverException(
#      82                     "'%s' executable needs to be in PATH. %s" % (
# ---> 83                         os.path.basename(self.path), self.start_error_message)
#      84                 )
#      85             elif err.errno == errno.EACCES:
#
# WebDriverException: Message: 'geckodriver' executable needs to be in PATH.

# %%
from itertools import chain 

ny = np.array([40.771985, -73.959106])

 
mp = folium.Map(location=ny, tiles='Stamen Toner', zoom_start=16, zoom_control=False)
    

mp

# %% [markdown]
# <h2>Data cleaning (done)</h2>

# %%
london = pd.read_csv('businesses-in-london.csv')

# %%
london = london.drop(london.columns[33:53], axis=1)

# %%
london = london.drop(['DissolutionDate', 'IncorporationDate',
       'Accounts.AccountRefDay', 'Accounts.AccountRefMonth',
       'Accounts.NextDueDate', 'Accounts.LastMadeUpDate',
       'Accounts.AccountCategory', 'Returns.NextDueDate',
       'Returns.LastMadeUpDate', 'Mortgages.NumMortCharges',
       'Mortgages.NumMortOutstanding', 'Mortgages.NumMortPartSatisfied',
       'Mortgages.NumMortSatisfied'], axis=1)

# %%
london = london.drop(['oa11','laua','ward','lsoa11', 'msoa11', 'wz11', 'calncv', 'stp'], axis=1)

# %%
london = london.drop(['CompanyNumber', 'RegAddress.CareOf', 'RegAddress.POBox',
       'RegAddress.AddressLine1', 'RegAddress.AddressLine2',
       'RegAddress.PostTown', 'RegAddress.County', 'RegAddress.Country',
       'LimitedPartnerships.NumGenPartners', 'LimitedPartnerships.NumLimPartners', 'URI', 'pcds'], axis=1)

# %%
london = london.drop(['CompanyCategory', 'CountryOfOrigin'], axis=1)

# %%
london.head()

# %%
london = london.rename({'CompanyName': 'Name', 'RegAddress.PostCode': 'PostCode',
            'SICCode.SicText_1': 'Text1', 'SICCode.SicText_2': 'Text2', 
            'SICCode.SicText_3': 'Text3', 'SICCode.SicText_4': 'Text4',
             'lat': 'Lat', 'long': 'Long'}, axis=1)

# %%
london.to_csv('london.csv')
