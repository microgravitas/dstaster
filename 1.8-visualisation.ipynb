# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Settings
# colors = {
#     'land': '',
#     'rest': '',
#     'port': '',
# }

# %%
# Load data
collection = pd.read_csv("tate/paintings.csv", index_col=0)

collection['groundtruth']
# Out:
# T13896     L
# T05010     O
# N05915     P
# N00530     L
# T00598     O
#           ..
# N05609     O
# T14823     P
# AL00397    O
# T14824     P
# T14825     P
# Name: groundtruth, Length: 2158, dtype: object

# %%
fig, axes = plt.subplots(3, 1, dpi=180, figsize=(8,6), sharex=True)

ax1, ax2, ax3 = axes
ax1.hist(collection['year'], bins=range(1550,2051,1))
ax3.hist(collection['year'], bins=range(1550,2051,10))
ax2.hist(collection['year'], bins=range(1550,2051,100))
ax2.set_ylabel("Number of paintings")
ax3.set_xlabel("Year")
ax3.set_xticks(range(1550,2051,50))
ax3.set_xticks(range(1550,2051,25), minor=True)

for ax in axes:
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
pass

# %%
fig, axes = plt.subplots(2, 1, dpi=180, figsize=(8,6))

ax1, ax2 = axes
ax1.hist(collection['width'], bins=50)
ax2.hist(collection['height'], bins=50)
ax1.set_ylabel("Number of paintings")
ax2.set_ylabel("Number of paintings")
ax1.set_xlabel("Width (mm)")
ax2.set_xlabel("Height (mm)")

# ax1.set_xticks(range(0,8001,1000))
# ax1.set_xticks(range(0,8001,500), minor=True)

# ax2.set_xticks(range(0,4001,1000))
# ax2.set_xticks(range(0,4001,500), minor=True)

ax1.set_xlim(0)
ax2.set_xlim(0)

for ax in axes:
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)

# %%
from matplotlib.ticker import ScalarFormatter

fig, axes = plt.subplots(1, 2, dpi=120, figsize=(8,4))

ax1, ax2 = axes

ax1.scatter(collection['width'], collection['height'], marker='+', alpha=.25)
ax2.scatter(collection['width'], collection['height'], marker='+', alpha=.25)

ax1.set_xlabel('Width (mm)')
ax1.set_ylabel('Height (mm)')
ax2.set_xlabel('Width (mm)')
# ax1.set_ylabel('Height (mm)')

ax2.set_xscale('log')
ax2.set_yscale('log')

ax2.xaxis.set_major_formatter(ScalarFormatter())
ax2.yaxis.set_major_formatter(ScalarFormatter())

for ax in axes:
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
