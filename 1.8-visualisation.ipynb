# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Settings
colors = {
    'land': '',
    'rest': '',
    'port': '',
}

# %%
# Load data
collection = pd.read_csv("tate/paintings.csv", index_col=0)

collection['groundtruth']
# Out:
# N01506     O
# T13896     L
# T05010     O
# N01615     O
# T02343     O
#           ..
# N05609     O
# T14823     P
# AL00397    O
# T14824     P
# T14825     P
# Name: groundtruth, Length: 3263, dtype: object

# %%
# fig, ax = plt.subplots()

# ax.hist(collection['year'], bins=range(1550,2051,50))

artists = collection['artist']

artists = artists.apply(lambda s: s.split(',')[0])

artists = artists.value_counts()

other = artists[10:].sum()
artists = artists[:10]
artists['other'] = other

artists
# Out:
# Joseph Mallord William Turner     235
# Walter Richard Sickert             37
# John Constable                     36
# Thomas Gainsborough                34
# Sir Joshua Reynolds                34
# John Singer Sargent                34
# George Frederic Watts              31
# Philip Wilson Steer                25
# Unknown artist                     25
# Adrian Stokes                      22
# other                            2750
# Name: artist, dtype: int64

# %%
fig, axes = plt.subplots(3, 1, dpi=180, figsize=(8,6), sharex=True)

ax1, ax2, ax3 = axes
ax1.hist(collection['year'], bins=range(1550,2051,1))
ax2.hist(collection['year'], bins=range(1550,2051,10))
ax3.hist(collection['year'], bins=range(1550,2051,100))
ax2.set_ylabel("Number of paintings")
ax3.set_xlabel("Year")

pass

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-2cc23b9c549a> in <module>
# ----> 1 fig, ax = plt.subplots(figsize=(6,6), dpi=120)
#       2
#       3 ax.set_xlabel('Width (mm)')
#       4 ax.set_ylabel('Height (mm)')
#       5
#
# NameError: name 'plt' is not defined
